# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rfdetr/pareto.png)
#
# The RF-DETR family of models stands as the quickest and most precise in object detection across all sizes. RF-DETR has achieved over 60 mAP on the Microsoft COCO benchmark, a leading measure of object detection performance. It also sets new records on RF100-VL, a benchmark that shows how well models adapt to real-world problems beyond standard datasets.
#
# The RF-DETR model group includes five sizes: Nano, Small, Medium, Base, and Large. These models offer a range of options for different needs. For example, RF-DETR-Nano is 11 mAP higher than YOLO11-n (on mAP50:95) and runs 0.17 ms faster. Likewise, RF-DETR-Small is 1.8 mAP better than YOLO11-x (the biggest YOLO11 model) and speeds things up by a good 7.77 ms. This wide range of models makes RF-DETR a great choice for many real-world uses, from small devices that need to be super fast to bigger jobs that demand top precision.
#
# RF-DETR is small enough to run on edge devices, making it perfect for deployments that need both high accuracy and real-time performance. You can easily get started with any of the RF-DETR models, as they're ready for training in the cloud with Roboflow or through the free RF-DETR Python package.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Nov  4 02:00:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   67C    P8             20W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies
#
# Installs RF-DETR version 1.2.1 or higher (which includes the new Nano, Small, and Medium checkpoints), along with Supervision for benchmarking and Roboflow for pulling datasets and uploading models to the Roboflow platform.

# %%
# !pip install -q rfdetr==1.2.1 supervision==0.26.1 roboflow

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=userdata.get("ROBOFLOW_API_KEY"))
# project = rf.workspace("roboflow-universe-projects").project("fall-detection-ca3o8")
# version = project.version(3)
# dataset = version.download("coco")

# project = rf.workspace("roboflow-universe-projects").project("fall-detection-ca3o8")
# version = project.version(4)
# dataset = version.download("coco")

project = rf.workspace("roboflow-universe-projects").project("fall-detection-ca3o8")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Fall-Detection-1 to coco:: 100%|██████████| 142586/142586 [00:02<00:00, 55933.81it/s]
# Extracting Dataset Version Zip to Fall-Detection-1 in coco:: 100%|██████████| 4505/4505 [00:00<00:00, 7752.10it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
from rfdetr import RFDETRMedium

model = RFDETRMedium()

model.train(dataset_dir=dataset.location, epochs=5, batch_size=8, grad_accum_steps=2)
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 2 classes
# reinitializing your detection head with 2 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=8, weight_decay=0.0001, epochs=5, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-medium.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=4, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/Fall-Detection-1', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=576, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=36, tensorboard=True, wandb=False, project=None, run=None, class_names=['Fall-Detected'], run_test=True, distributed=False)
# number of params: 33367236
# [736]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 196
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Epoch: [0]  [  0/196]  eta: 0:09:22  lr: 0.000100  class_error: 2.88  loss: 12.9838 (12.9838)  loss_ce: 1.2024 (1.2024)  loss_bbox: 0.8194 (0.8194)  loss_giou: 0.4674 (0.4674)  loss_ce_0: 1.1466 (1.1466)  loss_bbox_0: 1.0534 (1.0534)  loss_giou_0: 0.5698 (0.5698)  loss_ce_1: 1.1881 (1.1881)  loss_bbox_1: 0.8638 (0.8638)  loss_giou_1: 0.4848 (0.4848)  loss_ce_2: 1.2083 (1.2083)  loss_bbox_2: 0.8249 (0.8249)  loss_giou_2: 0.4563 (0.4563)  loss_ce_enc: 1.1379 (1.1379)  loss_bbox_enc: 0.9807 (0.9807)  loss_giou_enc: 0.5800 (0.5800)  loss_ce_unscaled: 1.2024 (1.2024)  class_error_unscaled: 2.8846 (2.8846)  loss_bbox_unscaled: 0.1639 (0.1639)  loss_giou_unscaled: 0.2337 (0.2337)  cardinality_error_unscaled: 139.5000 (139.5000)  loss_ce_0_unscaled: 1.1466 (1.1466)  loss_bbox_0_unscaled: 0.2107 (0.2107)  loss_giou_0_unscaled: 0.2849 (0.2849)  cardinality_error_0_unscaled: 305.0000 (305.0000)  loss_ce_1_unscaled: 1.1881 (1.1881)  loss_bbox_1_unscaled: 0.1728 (0.1728)  loss_giou_1_unscaled: 0.2424 (0.2424)  cardinality_error_1_unscaled: 334.0000 (334.0000)  loss_ce_2_unscaled: 1.2083 (1.2083)  loss_bbox_2_unscaled: 0.1650 (0.1650)  loss_giou_2_unscaled: 0.2282 (0.2282)  cardinality_error_2_unscaled: 232.3750 (232.3750)  loss_ce_enc_unscaled: 1.1379 (1.1379)  loss_bbox_enc_unscaled: 0.1961 (0.1961)  loss_giou_enc_unscaled: 0.2900 (0.2900)  cardinality_error_enc_unscaled: 1323.3750 (1323.3750)  time: 2.8708  data: 0.8761  max mem: 6407
# Epoch: [0]  [ 10/196]  eta: 0:03:28  lr: 0.000100  class_error: 0.00  loss: 10.1968 (10.4911)  loss_ce: 1.3256 (1.3038)  loss_bbox: 0.3798 (0.4209)  loss_giou: 0.2839 (0.3093)  loss_ce_0: 1.3035 (1.2791)  loss_bbox_0: 0.4670 (0.4887)  loss_giou_0: 0.3272 (0.3575)  loss_ce_1: 1.3082 (1.2913)  loss_bbox_1: 0.3954 (0.4361)  loss_giou_1: 0.2933 (0.3242)  loss_ce_2: 1.3218 (1.3036)  loss_bbox_2: 0.3520 (0.4192)  loss_giou_2: 0.2894 (0.3105)  loss_ce_enc: 1.2486 (1.2216)  loss_bbox_enc: 0.5195 (0.5838)  loss_giou_enc: 0.4006 (0.4415)  loss_ce_unscaled: 1.3256 (1.3038)  class_error_unscaled: 0.0000 (0.8866)  loss_bbox_unscaled: 0.0760 (0.0842)  loss_giou_unscaled: 0.1419 (0.1547)  cardinality_error_unscaled: 33.1250 (40.9659)  loss_ce_0_unscaled: 1.3035 (1.2791)  loss_bbox_0_unscaled: 0.0934 (0.0977)  loss_giou_0_unscaled: 0.1636 (0.1787)  cardinality_error_0_unscaled: 113.8750 (123.1023)  loss_ce_1_unscaled: 1.3082 (1.2913)  loss_bbox_1_unscaled: 0.0791 (0.0872)  loss_giou_1_unscaled: 0.1466 (0.1621)  cardinality_error_1_unscaled: 130.6250 (153.7955)  loss_ce_2_unscaled: 1.3218 (1.3036)  loss_bbox_2_unscaled: 0.0704 (0.0838)  loss_giou_2_unscaled: 0.1447 (0.1552)  cardinality_error_2_unscaled: 55.7500 (79.6364)  loss_ce_enc_unscaled: 1.2486 (1.2216)  loss_bbox_enc_unscaled: 0.1039 (0.1168)  loss_giou_enc_unscaled: 0.2003 (0.2207)  cardinality_error_enc_unscaled: 1102.6250 (1117.9205)  time: 1.1211  data: 0.1146  max mem: 7808
# Epoch: [0]  [ 20/196]  eta: 0:03:05  lr: 0.000100  class_error: 0.00  loss: 9.9809 (10.2224)  loss_ce: 1.3083 (1.2994)  loss_bbox: 0.3798 (0.4015)  loss_giou: 0.2839 (0.2972)  loss_ce_0: 1.3231 (1.3034)  loss_bbox_0: 0.3735 (0.4207)  loss_giou_0: 0.2776 (0.3200)  loss_ce_1: 1.3209 (1.3081)  loss_bbox_1: 0.3728 (0.4023)  loss_giou_1: 0.2870 (0.3025)  loss_ce_2: 1.3096 (1.3034)  loss_bbox_2: 0.3530 (0.4023)  loss_giou_2: 0.2894 (0.2981)  loss_ce_enc: 1.2506 (1.2526)  loss_bbox_enc: 0.4840 (0.5173)  loss_giou_enc: 0.3559 (0.3937)  loss_ce_unscaled: 1.3083 (1.2994)  class_error_unscaled: 0.0000 (0.4644)  loss_bbox_unscaled: 0.0760 (0.0803)  loss_giou_unscaled: 0.1419 (0.1486)  cardinality_error_unscaled: 1.1250 (21.9107)  loss_ce_0_unscaled: 1.3231 (1.3034)  loss_bbox_0_unscaled: 0.0747 (0.0841)  loss_giou_0_unscaled: 0.1388 (0.1600)  cardinality_error_0_unscaled: 34.6250 (76.8929)  loss_ce_1_unscaled: 1.3209 (1.3081)  loss_bbox_1_unscaled: 0.0746 (0.0805)  loss_giou_1_unscaled: 0.1435 (0.1513)  cardinality_error_1_unscaled: 37.1250 (91.4048)  loss_ce_2_unscaled: 1.3096 (1.3034)  loss_bbox_2_unscaled: 0.0706 (0.0805)  loss_giou_2_unscaled: 0.1447 (0.1490)  cardinality_error_2_unscaled: 10.2500 (43.4464)  loss_ce_enc_unscaled: 1.2506 (1.2526)  loss_bbox_enc_unscaled: 0.0968 (0.1035)  loss_giou_enc_unscaled: 0.1779 (0.1968)  cardinality_error_enc_unscaled: 766.1250 (880.2083)  time: 0.9605  data: 0.0391  max mem: 8220
# Epoch: [0]  [ 30/196]  eta: 0:02:48  lr: 0.000100  class_error: 0.00  loss: 9.6402 (10.0149)  loss_ce: 1.2620 (1.2753)  loss_bbox: 0.3555 (0.3933)  loss_giou: 0.2625 (0.2909)  loss_ce_0: 1.3346 (1.3137)  loss_bbox_0: 0.3225 (0.3917)  loss_giou_0: 0.2418 (0.3003)  loss_ce_1: 1.3079 (1.3043)  loss_bbox_1: 0.3589 (0.3864)  loss_giou_1: 0.2493 (0.2917)  loss_ce_2: 1.2608 (1.2633)  loss_bbox_2: 0.3721 (0.3979)  loss_giou_2: 0.2653 (0.2931)  loss_ce_enc: 1.3182 (1.2732)  loss_bbox_enc: 0.3642 (0.4767)  loss_giou_enc: 0.2794 (0.3630)  loss_ce_unscaled: 1.2620 (1.2753)  class_error_unscaled: 0.0000 (0.3146)  loss_bbox_unscaled: 0.0711 (0.0787)  loss_giou_unscaled: 0.1312 (0.1454)  cardinality_error_unscaled: 1.0000 (15.1613)  loss_ce_0_unscaled: 1.3346 (1.3137)  loss_bbox_0_unscaled: 0.0645 (0.0783)  loss_giou_0_unscaled: 0.1209 (0.1501)  cardinality_error_0_unscaled: 11.3750 (53.7903)  loss_ce_1_unscaled: 1.3079 (1.3043)  loss_bbox_1_unscaled: 0.0718 (0.0773)  loss_giou_1_unscaled: 0.1246 (0.1458)  cardinality_error_1_unscaled: 11.8750 (64.9919)  loss_ce_2_unscaled: 1.2608 (1.2633)  loss_bbox_2_unscaled: 0.0744 (0.0796)  loss_giou_2_unscaled: 0.1326 (0.1466)  cardinality_error_2_unscaled: 1.1250 (29.8548)  loss_ce_enc_unscaled: 1.3182 (1.2732)  loss_bbox_enc_unscaled: 0.0728 (0.0953)  loss_giou_enc_unscaled: 0.1397 (0.1815)  cardinality_error_enc_unscaled: 416.2500 (667.0766)  time: 0.9583  data: 0.0386  max mem: 8220
# Epoch: [0]  [ 40/196]  eta: 0:02:37  lr: 0.000100  class_error: 0.00  loss: 9.2383 (9.8776)  loss_ce: 1.1411 (1.2048)  loss_bbox: 0.3676 (0.4086)  loss_giou: 0.2681 (0.2980)  loss_ce_0: 1.3252 (1.3163)  loss_bbox_0: 0.2971 (0.3791)  loss_giou_0: 0.2517 (0.2919)  loss_ce_1: 1.2464 (1.2783)  loss_bbox_1: 0.3582 (0.3922)  loss_giou_1: 0.2663 (0.2930)  loss_ce_2: 1.0975 (1.2100)  loss_bbox_2: 0.3848 (0.4141)  loss_giou_2: 0.2736 (0.2999)  loss_ce_enc: 1.3220 (1.2825)  loss_bbox_enc: 0.3635 (0.4579)  loss_giou_enc: 0.2831 (0.3511)  loss_ce_unscaled: 1.1411 (1.2048)  class_error_unscaled: 0.0000 (0.2379)  loss_bbox_unscaled: 0.0735 (0.0817)  loss_giou_unscaled: 0.1341 (0.1490)  cardinality_error_unscaled: 1.0000 (11.7043)  loss_ce_0_unscaled: 1.3252 (1.3163)  loss_bbox_0_unscaled: 0.0594 (0.0758)  loss_giou_0_unscaled: 0.1258 (0.1459)  cardinality_error_0_unscaled: 1.2500 (41.0671)  loss_ce_1_unscaled: 1.2464 (1.2783)  loss_bbox_1_unscaled: 0.0716 (0.0784)  loss_giou_1_unscaled: 0.1331 (0.1465)  cardinality_error_1_unscaled: 1.2500 (49.5518)  loss_ce_2_unscaled: 1.0975 (1.2100)  loss_bbox_2_unscaled: 0.0770 (0.0828)  loss_giou_2_unscaled: 0.1368 (0.1499)  cardinality_error_2_unscaled: 1.0000 (22.8171)  loss_ce_enc_unscaled: 1.3220 (1.2825)  loss_bbox_enc_unscaled: 0.0727 (0.0916)  loss_giou_enc_unscaled: 0.1415 (0.1755)  cardinality_error_enc_unscaled: 78.7500 (512.1951)  time: 0.9682  data: 0.0375  max mem: 8220
# Epoch: [0]  [ 50/196]  eta: 0:02:25  lr: 0.000100  class_error: 0.00  loss: 8.8253 (9.6408)  loss_ce: 0.8856 (1.1291)  loss_bbox: 0.4089 (0.4115)  loss_giou: 0.2846 (0.2955)  loss_ce_0: 1.3252 (1.3200)  loss_bbox_0: 0.2971 (0.3625)  loss_giou_0: 0.2324 (0.2793)  loss_ce_1: 1.1591 (1.2490)  loss_bbox_1: 0.3747 (0.3897)  loss_giou_1: 0.2640 (0.2880)  loss_ce_2: 0.9624 (1.1440)  loss_bbox_2: 0.3956 (0.4134)  loss_giou_2: 0.2707 (0.2959)  loss_ce_enc: 1.3209 (1.2925)  loss_bbox_enc: 0.3523 (0.4347)  loss_giou_enc: 0.2956 (0.3355)  loss_ce_unscaled: 0.8856 (1.1291)  class_error_unscaled: 0.0000 (0.1912)  loss_bbox_unscaled: 0.0818 (0.0823)  loss_giou_unscaled: 0.1423 (0.1478)  cardinality_error_unscaled: 1.0000 (9.6005)  loss_ce_0_unscaled: 1.3252 (1.3200)  loss_bbox_0_unscaled: 0.0594 (0.0725)  loss_giou_0_unscaled: 0.1162 (0.1396)  cardinality_error_0_unscaled: 1.0000 (33.2083)  loss_ce_1_unscaled: 1.1591 (1.2490)  loss_bbox_1_unscaled: 0.0749 (0.0779)  loss_giou_1_unscaled: 0.1320 (0.1440)  cardinality_error_1_unscaled: 1.0000 (40.0490)  loss_ce_2_unscaled: 0.9624 (1.1440)  loss_bbox_2_unscaled: 0.0791 (0.0827)  loss_giou_2_unscaled: 0.1353 (0.1480)  cardinality_error_2_unscaled: 1.0000 (18.5368)  loss_ce_enc_unscaled: 1.3209 (1.2925)  loss_bbox_enc_unscaled: 0.0705 (0.0869)  loss_giou_enc_unscaled: 0.1478 (0.1678)  cardinality_error_enc_unscaled: 5.6250 (413.0417)  time: 0.9720  data: 0.0381  max mem: 8220
# Epoch: [0]  [ 60/196]  eta: 0:02:14  lr: 0.000100  class_error: 0.00  loss: 8.4297 (9.4545)  loss_ce: 0.8053 (1.0690)  loss_bbox: 0.4334 (0.4145)  loss_giou: 0.2883 (0.2976)  loss_ce_0: 1.3457 (1.3277)  loss_bbox_0: 0.2719 (0.3488)  loss_giou_0: 0.2019 (0.2713)  loss_ce_1: 1.1033 (1.2131)  loss_bbox_1: 0.3747 (0.3888)  loss_giou_1: 0.2531 (0.2875)  loss_ce_2: 0.8272 (1.0870)  loss_bbox_2: 0.4022 (0.4144)  loss_giou_2: 0.2784 (0.2974)  loss_ce_enc: 1.3404 (1.2999)  loss_bbox_enc: 0.3153 (0.4150)  loss_giou_enc: 0.2499 (0.3225)  loss_ce_unscaled: 0.8053 (1.0690)  class_error_unscaled: 0.0000 (0.1599)  loss_bbox_unscaled: 0.0867 (0.0829)  loss_giou_unscaled: 0.1442 (0.1488)  cardinality_error_unscaled: 1.0000 (8.1988)  loss_ce_0_unscaled: 1.3457 (1.3277)  loss_bbox_0_unscaled: 0.0544 (0.0698)  loss_giou_0_unscaled: 0.1009 (0.1357)  cardinality_error_0_unscaled: 1.0000 (27.9180)  loss_ce_1_unscaled: 1.1033 (1.2131)  loss_bbox_1_unscaled: 0.0749 (0.0778)  loss_giou_1_unscaled: 0.1265 (0.1437)  cardinality_error_1_unscaled: 1.0000 (33.6434)  loss_ce_2_unscaled: 0.8272 (1.0870)  loss_bbox_2_unscaled: 0.0804 (0.0829)  loss_giou_2_unscaled: 0.1392 (0.1487)  cardinality_error_2_unscaled: 1.0000 (15.6680)  loss_ce_enc_unscaled: 1.3404 (1.2999)  loss_bbox_enc_unscaled: 0.0631 (0.0830)  loss_giou_enc_unscaled: 0.1249 (0.1612)  cardinality_error_enc_unscaled: 1.3750 (345.5164)  time: 0.9351  data: 0.0379  max mem: 8220
# Epoch: [0]  [ 70/196]  eta: 0:02:04  lr: 0.000100  class_error: 0.00  loss: 8.4297 (9.3068)  loss_ce: 0.7699 (1.0235)  loss_bbox: 0.4735 (0.4246)  loss_giou: 0.3014 (0.2992)  loss_ce_0: 1.3616 (1.3322)  loss_bbox_0: 0.2628 (0.3365)  loss_giou_0: 0.1891 (0.2628)  loss_ce_1: 0.9916 (1.1749)  loss_bbox_1: 0.3991 (0.3914)  loss_giou_1: 0.2763 (0.2862)  loss_ce_2: 0.8030 (1.0430)  loss_bbox_2: 0.4607 (0.4219)  loss_giou_2: 0.2924 (0.2985)  loss_ce_enc: 1.3571 (1.3089)  loss_bbox_enc: 0.2873 (0.3953)  loss_giou_enc: 0.2146 (0.3080)  loss_ce_unscaled: 0.7699 (1.0235)  class_error_unscaled: 0.0000 (0.1374)  loss_bbox_unscaled: 0.0947 (0.0849)  loss_giou_unscaled: 0.1507 (0.1496)  cardinality_error_unscaled: 1.0000 (7.1866)  loss_ce_0_unscaled: 1.3616 (1.3322)  loss_bbox_0_unscaled: 0.0526 (0.0673)  loss_giou_0_unscaled: 0.0946 (0.1314)  cardinality_error_0_unscaled: 1.0000 (24.1268)  loss_ce_1_unscaled: 0.9916 (1.1749)  loss_bbox_1_unscaled: 0.0798 (0.0783)  loss_giou_1_unscaled: 0.1382 (0.1431)  cardinality_error_1_unscaled: 1.0000 (29.0458)  loss_ce_2_unscaled: 0.8030 (1.0430)  loss_bbox_2_unscaled: 0.0921 (0.0844)  loss_giou_2_unscaled: 0.1462 (0.1493)  cardinality_error_2_unscaled: 1.0000 (13.6602)  loss_ce_enc_unscaled: 1.3571 (1.3089)  loss_bbox_enc_unscaled: 0.0575 (0.0791)  loss_giou_enc_unscaled: 0.1073 (0.1540)  cardinality_error_enc_unscaled: 1.0000 (296.9965)  time: 0.9478  data: 0.0387  max mem: 8220
# Epoch: [0]  [ 80/196]  eta: 0:01:53  lr: 0.000100  class_error: 0.00  loss: 8.4594 (9.1992)  loss_ce: 0.7070 (0.9793)  loss_bbox: 0.4741 (0.4306)  loss_giou: 0.2965 (0.2996)  loss_ce_0: 1.3427 (1.3297)  loss_bbox_0: 0.2651 (0.3371)  loss_giou_0: 0.2079 (0.2600)  loss_ce_1: 0.8921 (1.1368)  loss_bbox_1: 0.4065 (0.3996)  loss_giou_1: 0.2763 (0.2877)  loss_ce_2: 0.7410 (1.0000)  loss_bbox_2: 0.4660 (0.4302)  loss_giou_2: 0.2955 (0.3003)  loss_ce_enc: 1.3678 (1.3150)  loss_bbox_enc: 0.2873 (0.3923)  loss_giou_enc: 0.2075 (0.3009)  loss_ce_unscaled: 0.7070 (0.9793)  class_error_unscaled: 0.0000 (0.1204)  loss_bbox_unscaled: 0.0948 (0.0861)  loss_giou_unscaled: 0.1483 (0.1498)  cardinality_error_unscaled: 0.8750 (6.4120)  loss_ce_0_unscaled: 1.3427 (1.3297)  loss_bbox_0_unscaled: 0.0530 (0.0674)  loss_giou_0_unscaled: 0.1040 (0.1300)  cardinality_error_0_unscaled: 1.0000 (21.2731)  loss_ce_1_unscaled: 0.8921 (1.1368)  loss_bbox_1_unscaled: 0.0813 (0.0799)  loss_giou_1_unscaled: 0.1382 (0.1438)  cardinality_error_1_unscaled: 1.0000 (25.5787)  loss_ce_2_unscaled: 0.7410 (1.0000)  loss_bbox_2_unscaled: 0.0932 (0.0860)  loss_giou_2_unscaled: 0.1477 (0.1502)  cardinality_error_2_unscaled: 1.0000 (12.0926)  loss_ce_enc_unscaled: 1.3678 (1.3150)  loss_bbox_enc_unscaled: 0.0575 (0.0785)  loss_giou_enc_unscaled: 0.1037 (0.1505)  cardinality_error_enc_unscaled: 1.0000 (260.4506)  time: 0.9451  data: 0.0388  max mem: 8220
# Epoch: [0]  [ 90/196]  eta: 0:01:42  lr: 0.000100  class_error: 0.00  loss: 8.4571 (9.1351)  loss_ce: 0.6854 (0.9568)  loss_bbox: 0.4665 (0.4362)  loss_giou: 0.2868 (0.3036)  loss_ce_0: 1.3072 (1.3261)  loss_bbox_0: 0.2981 (0.3334)  loss_giou_0: 0.2179 (0.2590)  loss_ce_1: 0.8684 (1.1114)  loss_bbox_1: 0.4175 (0.4037)  loss_giou_1: 0.2890 (0.2907)  loss_ce_2: 0.7276 (0.9788)  loss_bbox_2: 0.4773 (0.4337)  loss_giou_2: 0.2955 (0.3030)  loss_ce_enc: 1.3678 (1.3193)  loss_bbox_enc: 0.2951 (0.3836)  loss_giou_enc: 0.2354 (0.2959)  loss_ce_unscaled: 0.6854 (0.9568)  class_error_unscaled: 0.0000 (0.1072)  loss_bbox_unscaled: 0.0933 (0.0872)  loss_giou_unscaled: 0.1434 (0.1518)  cardinality_error_unscaled: 0.8750 (5.8063)  loss_ce_0_unscaled: 1.3072 (1.3261)  loss_bbox_0_unscaled: 0.0596 (0.0667)  loss_giou_0_unscaled: 0.1090 (0.1295)  cardinality_error_0_unscaled: 1.0000 (19.0453)  loss_ce_1_unscaled: 0.8684 (1.1114)  loss_bbox_1_unscaled: 0.0835 (0.0807)  loss_giou_1_unscaled: 0.1445 (0.1454)  cardinality_error_1_unscaled: 1.0000 (22.8723)  loss_ce_2_unscaled: 0.7276 (0.9788)  loss_bbox_2_unscaled: 0.0955 (0.0867)  loss_giou_2_unscaled: 0.1477 (0.1515)  cardinality_error_2_unscaled: 1.0000 (10.8970)  loss_ce_enc_unscaled: 1.3678 (1.3193)  loss_bbox_enc_unscaled: 0.0590 (0.0767)  loss_giou_enc_unscaled: 0.1177 (0.1479)  cardinality_error_enc_unscaled: 1.0000 (231.9423)  time: 0.9056  data: 0.0374  max mem: 8220
# Epoch: [0]  [100/196]  eta: 0:01:32  lr: 0.000100  class_error: 0.00  loss: 8.3415 (9.0506)  loss_ce: 0.7257 (0.9318)  loss_bbox: 0.4357 (0.4352)  loss_giou: 0.2826 (0.3032)  loss_ce_0: 1.2980 (1.3225)  loss_bbox_0: 0.2907 (0.3302)  loss_giou_0: 0.2218 (0.2574)  loss_ce_1: 0.8702 (1.0867)  loss_bbox_1: 0.4162 (0.4054)  loss_giou_1: 0.2901 (0.2916)  loss_ce_2: 0.7611 (0.9557)  loss_bbox_2: 0.4309 (0.4335)  loss_giou_2: 0.2898 (0.3032)  loss_ce_enc: 1.3684 (1.3244)  loss_bbox_enc: 0.2951 (0.3773)  loss_giou_enc: 0.2544 (0.2926)  loss_ce_unscaled: 0.7257 (0.9318)  class_error_unscaled: 0.0000 (0.0966)  loss_bbox_unscaled: 0.0871 (0.0870)  loss_giou_unscaled: 0.1413 (0.1516)  cardinality_error_unscaled: 1.0000 (5.3280)  loss_ce_0_unscaled: 1.2980 (1.3225)  loss_bbox_0_unscaled: 0.0581 (0.0660)  loss_giou_0_unscaled: 0.1109 (0.1287)  cardinality_error_0_unscaled: 1.0000 (17.2574)  loss_ce_1_unscaled: 0.8702 (1.0867)  loss_bbox_1_unscaled: 0.0832 (0.0811)  loss_giou_1_unscaled: 0.1451 (0.1458)  cardinality_error_1_unscaled: 0.8750 (20.6968)  loss_ce_2_unscaled: 0.7611 (0.9557)  loss_bbox_2_unscaled: 0.0862 (0.0867)  loss_giou_2_unscaled: 0.1449 (0.1516)  cardinality_error_2_unscaled: 1.0000 (9.9517)  loss_ce_enc_unscaled: 1.3684 (1.3244)  loss_bbox_enc_unscaled: 0.0590 (0.0755)  loss_giou_enc_unscaled: 0.1272 (0.1463)  cardinality_error_enc_unscaled: 1.0000 (209.0743)  time: 0.9217  data: 0.0396  max mem: 8220
# Epoch: [0]  [110/196]  eta: 0:01:22  lr: 0.000100  class_error: 0.00  loss: 8.2680 (8.9639)  loss_ce: 0.6513 (0.9082)  loss_bbox: 0.4358 (0.4363)  loss_giou: 0.2855 (0.3039)  loss_ce_0: 1.2875 (1.3192)  loss_bbox_0: 0.2933 (0.3287)  loss_giou_0: 0.2222 (0.2558)  loss_ce_1: 0.7934 (1.0592)  loss_bbox_1: 0.4232 (0.4076)  loss_giou_1: 0.2967 (0.2923)  loss_ce_2: 0.6682 (0.9316)  loss_bbox_2: 0.4514 (0.4348)  loss_giou_2: 0.3102 (0.3037)  loss_ce_enc: 1.3596 (1.3277)  loss_bbox_enc: 0.2679 (0.3682)  loss_giou_enc: 0.2292 (0.2868)  loss_ce_unscaled: 0.6513 (0.9082)  class_error_unscaled: 0.0000 (0.0879)  loss_bbox_unscaled: 0.0872 (0.0873)  loss_giou_unscaled: 0.1428 (0.1519)  cardinality_error_unscaled: 1.0000 (4.9313)  loss_ce_0_unscaled: 1.2875 (1.3192)  loss_bbox_0_unscaled: 0.0587 (0.0657)  loss_giou_0_unscaled: 0.1111 (0.1279)  cardinality_error_0_unscaled: 1.0000 (15.7905)  loss_ce_1_unscaled: 0.7934 (1.0592)  loss_bbox_1_unscaled: 0.0846 (0.0815)  loss_giou_1_unscaled: 0.1484 (0.1461)  cardinality_error_1_unscaled: 1.0000 (18.9302)  loss_ce_2_unscaled: 0.6682 (0.9316)  loss_bbox_2_unscaled: 0.0903 (0.0870)  loss_giou_2_unscaled: 0.1551 (0.1519)  cardinality_error_2_unscaled: 1.0000 (9.2106)  loss_ce_enc_unscaled: 1.3596 (1.3277)  loss_bbox_enc_unscaled: 0.0536 (0.0736)  loss_giou_enc_unscaled: 0.1146 (0.1434)  cardinality_error_enc_unscaled: 1.0000 (190.3311)  time: 0.9447  data: 0.0410  max mem: 8220
# Epoch: [0]  [120/196]  eta: 0:01:13  lr: 0.000100  class_error: 0.00  loss: 8.2810 (8.9265)  loss_ce: 0.6636 (0.8911)  loss_bbox: 0.5093 (0.4434)  loss_giou: 0.3065 (0.3051)  loss_ce_0: 1.2416 (1.3090)  loss_bbox_0: 0.3168 (0.3333)  loss_giou_0: 0.2565 (0.2565)  loss_ce_1: 0.7889 (1.0386)  loss_bbox_1: 0.4398 (0.4149)  loss_giou_1: 0.3070 (0.2937)  loss_ce_2: 0.6824 (0.9159)  loss_bbox_2: 0.5086 (0.4407)  loss_giou_2: 0.3090 (0.3044)  loss_ce_enc: 1.3622 (1.3308)  loss_bbox_enc: 0.2632 (0.3655)  loss_giou_enc: 0.2275 (0.2836)  loss_ce_unscaled: 0.6636 (0.8911)  class_error_unscaled: 0.0000 (0.0806)  loss_bbox_unscaled: 0.1019 (0.0887)  loss_giou_unscaled: 0.1532 (0.1526)  cardinality_error_unscaled: 1.0000 (4.6229)  loss_ce_0_unscaled: 1.2416 (1.3090)  loss_bbox_0_unscaled: 0.0634 (0.0667)  loss_giou_0_unscaled: 0.1282 (0.1282)  cardinality_error_0_unscaled: 1.0000 (14.5682)  loss_ce_1_unscaled: 0.7889 (1.0386)  loss_bbox_1_unscaled: 0.0880 (0.0830)  loss_giou_1_unscaled: 0.1535 (0.1469)  cardinality_error_1_unscaled: 1.0000 (17.4669)  loss_ce_2_unscaled: 0.6824 (0.9159)  loss_bbox_2_unscaled: 0.1017 (0.0881)  loss_giou_2_unscaled: 0.1545 (0.1522)  cardinality_error_2_unscaled: 1.2500 (8.5919)  loss_ce_enc_unscaled: 1.3622 (1.3308)  loss_bbox_enc_unscaled: 0.0526 (0.0731)  loss_giou_enc_unscaled: 0.1138 (0.1418)  cardinality_error_enc_unscaled: 1.0000 (174.6932)  time: 0.9455  data: 0.0386  max mem: 8220
# Epoch: [0]  [130/196]  eta: 0:01:03  lr: 0.000100  class_error: 0.00  loss: 8.2810 (8.8624)  loss_ce: 0.6650 (0.8725)  loss_bbox: 0.5107 (0.4468)  loss_giou: 0.3081 (0.3065)  loss_ce_0: 1.1603 (1.2976)  loss_bbox_0: 0.3490 (0.3339)  loss_giou_0: 0.2565 (0.2573)  loss_ce_1: 0.7889 (1.0185)  loss_bbox_1: 0.4467 (0.4166)  loss_giou_1: 0.2882 (0.2946)  loss_ce_2: 0.6824 (0.8965)  loss_bbox_2: 0.5086 (0.4441)  loss_giou_2: 0.3090 (0.3057)  loss_ce_enc: 1.3746 (1.3334)  loss_bbox_enc: 0.2871 (0.3585)  loss_giou_enc: 0.2275 (0.2797)  loss_ce_unscaled: 0.6650 (0.8725)  class_error_unscaled: 0.0000 (0.0744)  loss_bbox_unscaled: 0.1021 (0.0894)  loss_giou_unscaled: 0.1540 (0.1532)  cardinality_error_unscaled: 1.0000 (4.3445)  loss_ce_0_unscaled: 1.1603 (1.2976)  loss_bbox_0_unscaled: 0.0698 (0.0668)  loss_giou_0_unscaled: 0.1282 (0.1287)  cardinality_error_0_unscaled: 1.0000 (13.5334)  loss_ce_1_unscaled: 0.7889 (1.0185)  loss_bbox_1_unscaled: 0.0893 (0.0833)  loss_giou_1_unscaled: 0.1441 (0.1473)  cardinality_error_1_unscaled: 1.0000 (16.2109)  loss_ce_2_unscaled: 0.6824 (0.8965)  loss_bbox_2_unscaled: 0.1017 (0.0888)  loss_giou_2_unscaled: 0.1545 (0.1528)  cardinality_error_2_unscaled: 1.0000 (8.0239)  loss_ce_enc_unscaled: 1.3746 (1.3334)  loss_bbox_enc_unscaled: 0.0574 (0.0717)  loss_giou_enc_unscaled: 0.1138 (0.1399)  cardinality_error_enc_unscaled: 1.0000 (161.4313)  time: 0.9493  data: 0.0452  max mem: 8220
# Epoch: [0]  [140/196]  eta: 0:00:53  lr: 0.000100  class_error: 0.00  loss: 8.2747 (8.8453)  loss_ce: 0.6955 (0.8620)  loss_bbox: 0.4471 (0.4509)  loss_giou: 0.3121 (0.3094)  loss_ce_0: 1.1520 (1.2877)  loss_bbox_0: 0.3461 (0.3386)  loss_giou_0: 0.2679 (0.2604)  loss_ce_1: 0.8277 (1.0049)  loss_bbox_1: 0.4467 (0.4210)  loss_giou_1: 0.2916 (0.2975)  loss_ce_2: 0.7014 (0.8848)  loss_bbox_2: 0.4597 (0.4492)  loss_giou_2: 0.3139 (0.3092)  loss_ce_enc: 1.3553 (1.3346)  loss_bbox_enc: 0.2886 (0.3560)  loss_giou_enc: 0.2466 (0.2790)  loss_ce_unscaled: 0.6955 (0.8620)  class_error_unscaled: 0.0000 (0.0692)  loss_bbox_unscaled: 0.0894 (0.0902)  loss_giou_unscaled: 0.1560 (0.1547)  cardinality_error_unscaled: 1.0000 (4.1046)  loss_ce_0_unscaled: 1.1520 (1.2877)  loss_bbox_0_unscaled: 0.0692 (0.0677)  loss_giou_0_unscaled: 0.1339 (0.1302)  cardinality_error_0_unscaled: 1.0000 (12.6436)  loss_ce_1_unscaled: 0.8277 (1.0049)  loss_bbox_1_unscaled: 0.0893 (0.0842)  loss_giou_1_unscaled: 0.1458 (0.1488)  cardinality_error_1_unscaled: 1.0000 (15.1303)  loss_ce_2_unscaled: 0.7014 (0.8848)  loss_bbox_2_unscaled: 0.0919 (0.0898)  loss_giou_2_unscaled: 0.1569 (0.1546)  cardinality_error_2_unscaled: 0.8750 (7.5222)  loss_ce_enc_unscaled: 1.3553 (1.3346)  loss_bbox_enc_unscaled: 0.0577 (0.0712)  loss_giou_enc_unscaled: 0.1233 (0.1395)  cardinality_error_enc_unscaled: 1.0000 (150.0541)  time: 0.9545  data: 0.0466  max mem: 8220
# Epoch: [0]  [150/196]  eta: 0:00:44  lr: 0.000100  class_error: 0.00  loss: 8.2866 (8.8062)  loss_ce: 0.7071 (0.8496)  loss_bbox: 0.4471 (0.4522)  loss_giou: 0.3242 (0.3114)  loss_ce_0: 1.1161 (1.2746)  loss_bbox_0: 0.3703 (0.3435)  loss_giou_0: 0.2739 (0.2636)  loss_ce_1: 0.7538 (0.9863)  loss_bbox_1: 0.4348 (0.4246)  loss_giou_1: 0.3044 (0.3004)  loss_ce_2: 0.7198 (0.8712)  loss_bbox_2: 0.4501 (0.4511)  loss_giou_2: 0.3174 (0.3111)  loss_ce_enc: 1.3354 (1.3341)  loss_bbox_enc: 0.3005 (0.3545)  loss_giou_enc: 0.2602 (0.2780)  loss_ce_unscaled: 0.7071 (0.8496)  class_error_unscaled: 0.0000 (0.0646)  loss_bbox_unscaled: 0.0894 (0.0904)  loss_giou_unscaled: 0.1621 (0.1557)  cardinality_error_unscaled: 1.0000 (3.8974)  loss_ce_0_unscaled: 1.1161 (1.2746)  loss_bbox_0_unscaled: 0.0741 (0.0687)  loss_giou_0_unscaled: 0.1370 (0.1318)  cardinality_error_0_unscaled: 1.0000 (11.8717)  loss_ce_1_unscaled: 0.7538 (0.9863)  loss_bbox_1_unscaled: 0.0870 (0.0849)  loss_giou_1_unscaled: 0.1522 (0.1502)  cardinality_error_1_unscaled: 1.0000 (14.1921)  loss_ce_2_unscaled: 0.7198 (0.8712)  loss_bbox_2_unscaled: 0.0900 (0.0902)  loss_giou_2_unscaled: 0.1587 (0.1556)  cardinality_error_2_unscaled: 0.8750 (7.0993)  loss_ce_enc_unscaled: 1.3354 (1.3341)  loss_bbox_enc_unscaled: 0.0601 (0.0709)  loss_giou_enc_unscaled: 0.1301 (0.1390)  cardinality_error_enc_unscaled: 1.0000 (140.1829)  time: 0.9600  data: 0.0394  max mem: 8220
# Epoch: [0]  [160/196]  eta: 0:00:34  lr: 0.000100  class_error: -0.00  loss: 7.8951 (8.7364)  loss_ce: 0.6247 (0.8348)  loss_bbox: 0.4342 (0.4524)  loss_giou: 0.2953 (0.3109)  loss_ce_0: 1.0868 (1.2621)  loss_bbox_0: 0.3579 (0.3436)  loss_giou_0: 0.2631 (0.2630)  loss_ce_1: 0.7129 (0.9686)  loss_bbox_1: 0.4157 (0.4247)  loss_giou_1: 0.3044 (0.2998)  loss_ce_2: 0.6381 (0.8556)  loss_bbox_2: 0.4217 (0.4506)  loss_giou_2: 0.3094 (0.3104)  loss_ce_enc: 1.3417 (1.3351)  loss_bbox_enc: 0.2710 (0.3496)  loss_giou_enc: 0.2367 (0.2752)  loss_ce_unscaled: 0.6247 (0.8348)  class_error_unscaled: 0.0000 (0.0606)  loss_bbox_unscaled: 0.0868 (0.0905)  loss_giou_unscaled: 0.1477 (0.1554)  cardinality_error_unscaled: 1.0000 (3.7158)  loss_ce_0_unscaled: 1.0868 (1.2621)  loss_bbox_0_unscaled: 0.0716 (0.0687)  loss_giou_0_unscaled: 0.1315 (0.1315)  cardinality_error_0_unscaled: 1.0000 (11.1949)  loss_ce_1_unscaled: 0.7129 (0.9686)  loss_bbox_1_unscaled: 0.0831 (0.0849)  loss_giou_1_unscaled: 0.1522 (0.1499)  cardinality_error_1_unscaled: 1.0000 (13.3703)  loss_ce_2_unscaled: 0.6381 (0.8556)  loss_bbox_2_unscaled: 0.0843 (0.0901)  loss_giou_2_unscaled: 0.1547 (0.1552)  cardinality_error_2_unscaled: 1.0000 (6.7259)  loss_ce_enc_unscaled: 1.3417 (1.3351)  loss_bbox_enc_unscaled: 0.0542 (0.0699)  loss_giou_enc_unscaled: 0.1183 (0.1376)  cardinality_error_enc_unscaled: 1.0000 (131.5373)  time: 0.9780  data: 0.0380  max mem: 8220
# Epoch: [0]  [170/196]  eta: 0:00:24  lr: 0.000100  class_error: 0.00  loss: 7.6110 (8.6791)  loss_ce: 0.6164 (0.8241)  loss_bbox: 0.4308 (0.4528)  loss_giou: 0.2701 (0.3086)  loss_ce_0: 1.0616 (1.2497)  loss_bbox_0: 0.3579 (0.3464)  loss_giou_0: 0.2376 (0.2620)  loss_ce_1: 0.6946 (0.9540)  loss_bbox_1: 0.4055 (0.4257)  loss_giou_1: 0.2617 (0.2978)  loss_ce_2: 0.6216 (0.8440)  loss_bbox_2: 0.4167 (0.4509)  loss_giou_2: 0.2678 (0.3082)  loss_ce_enc: 1.3434 (1.3339)  loss_bbox_enc: 0.2820 (0.3488)  loss_giou_enc: 0.2135 (0.2723)  loss_ce_unscaled: 0.6164 (0.8241)  class_error_unscaled: 0.0000 (0.0570)  loss_bbox_unscaled: 0.0862 (0.0906)  loss_giou_unscaled: 0.1350 (0.1543)  cardinality_error_unscaled: 1.0000 (3.5599)  loss_ce_0_unscaled: 1.0616 (1.2497)  loss_bbox_0_unscaled: 0.0716 (0.0693)  loss_giou_0_unscaled: 0.1188 (0.1310)  cardinality_error_0_unscaled: 1.0000 (10.5994)  loss_ce_1_unscaled: 0.6946 (0.9540)  loss_bbox_1_unscaled: 0.0811 (0.0851)  loss_giou_1_unscaled: 0.1308 (0.1489)  cardinality_error_1_unscaled: 1.0000 (12.6455)  loss_ce_2_unscaled: 0.6216 (0.8440)  loss_bbox_2_unscaled: 0.0833 (0.0902)  loss_giou_2_unscaled: 0.1339 (0.1541)  cardinality_error_2_unscaled: 1.0000 (6.4211)  loss_ce_enc_unscaled: 1.3434 (1.3339)  loss_bbox_enc_unscaled: 0.0564 (0.0698)  loss_giou_enc_unscaled: 0.1068 (0.1362)  cardinality_error_enc_unscaled: 1.0000 (123.9064)  time: 0.9380  data: 0.0378  max mem: 8220
# Epoch: [0]  [180/196]  eta: 0:00:15  lr: 0.000100  class_error: 0.00  loss: 7.6874 (8.6294)  loss_ce: 0.6634 (0.8165)  loss_bbox: 0.4143 (0.4505)  loss_giou: 0.2701 (0.3075)  loss_ce_0: 1.0481 (1.2399)  loss_bbox_0: 0.3617 (0.3462)  loss_giou_0: 0.2449 (0.2616)  loss_ce_1: 0.7286 (0.9434)  loss_bbox_1: 0.4113 (0.4248)  loss_giou_1: 0.2716 (0.2974)  loss_ce_2: 0.6447 (0.8361)  loss_bbox_2: 0.4185 (0.4490)  loss_giou_2: 0.2760 (0.3071)  loss_ce_enc: 1.3107 (1.3320)  loss_bbox_enc: 0.2947 (0.3464)  loss_giou_enc: 0.2301 (0.2709)  loss_ce_unscaled: 0.6634 (0.8165)  class_error_unscaled: 0.0000 (0.0539)  loss_bbox_unscaled: 0.0829 (0.0901)  loss_giou_unscaled: 0.1350 (0.1537)  cardinality_error_unscaled: 1.0000 (3.4171)  loss_ce_0_unscaled: 1.0481 (1.2399)  loss_bbox_0_unscaled: 0.0723 (0.0692)  loss_giou_0_unscaled: 0.1224 (0.1308)  cardinality_error_0_unscaled: 1.0000 (10.0684)  loss_ce_1_unscaled: 0.7286 (0.9434)  loss_bbox_1_unscaled: 0.0823 (0.0850)  loss_giou_1_unscaled: 0.1358 (0.1487)  cardinality_error_1_unscaled: 1.0000 (12.0014)  loss_ce_2_unscaled: 0.6447 (0.8361)  loss_bbox_2_unscaled: 0.0837 (0.0898)  loss_giou_2_unscaled: 0.1380 (0.1536)  cardinality_error_2_unscaled: 1.0000 (6.1222)  loss_ce_enc_unscaled: 1.3107 (1.3320)  loss_bbox_enc_unscaled: 0.0589 (0.0693)  loss_giou_enc_unscaled: 0.1150 (0.1354)  cardinality_error_enc_unscaled: 1.0000 (117.1243)  time: 0.8858  data: 0.0376  max mem: 8220
# Epoch: [0]  [190/196]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 7.8578 (8.6138)  loss_ce: 0.6880 (0.8103)  loss_bbox: 0.4150 (0.4517)  loss_giou: 0.3074 (0.3095)  loss_ce_0: 1.0550 (1.2296)  loss_bbox_0: 0.3617 (0.3491)  loss_giou_0: 0.2740 (0.2645)  loss_ce_1: 0.7672 (0.9351)  loss_bbox_1: 0.4178 (0.4266)  loss_giou_1: 0.2978 (0.2996)  loss_ce_2: 0.6956 (0.8291)  loss_bbox_2: 0.4251 (0.4511)  loss_giou_2: 0.2992 (0.3097)  loss_ce_enc: 1.3107 (1.3313)  loss_bbox_enc: 0.2947 (0.3450)  loss_giou_enc: 0.2547 (0.2717)  loss_ce_unscaled: 0.6880 (0.8103)  class_error_unscaled: 0.0000 (0.0511)  loss_bbox_unscaled: 0.0830 (0.0903)  loss_giou_unscaled: 0.1537 (0.1547)  cardinality_error_unscaled: 1.0000 (3.2978)  loss_ce_0_unscaled: 1.0550 (1.2296)  loss_bbox_0_unscaled: 0.0723 (0.0698)  loss_giou_0_unscaled: 0.1370 (0.1323)  cardinality_error_0_unscaled: 1.0000 (9.5936)  loss_ce_1_unscaled: 0.7672 (0.9351)  loss_bbox_1_unscaled: 0.0836 (0.0853)  loss_giou_1_unscaled: 0.1489 (0.1498)  cardinality_error_1_unscaled: 1.0000 (11.4241)  loss_ce_2_unscaled: 0.6956 (0.8291)  loss_bbox_2_unscaled: 0.0850 (0.0902)  loss_giou_2_unscaled: 0.1496 (0.1548)  cardinality_error_2_unscaled: 1.0000 (5.9228)  loss_ce_enc_unscaled: 1.3107 (1.3313)  loss_bbox_enc_unscaled: 0.0589 (0.0690)  loss_giou_enc_unscaled: 0.1273 (0.1358)  cardinality_error_enc_unscaled: 1.0000 (111.0445)  time: 0.9033  data: 0.0372  max mem: 8220
# Epoch: [0]  [195/196]  eta: 0:00:00  lr: 0.000100  class_error: 0.00  loss: 7.8286 (8.6026)  loss_ce: 0.7099 (0.8088)  loss_bbox: 0.4143 (0.4508)  loss_giou: 0.3074 (0.3095)  loss_ce_0: 1.0550 (1.2246)  loss_bbox_0: 0.3625 (0.3504)  loss_giou_0: 0.2740 (0.2657)  loss_ce_1: 0.7948 (0.9319)  loss_bbox_1: 0.4178 (0.4257)  loss_giou_1: 0.2845 (0.2997)  loss_ce_2: 0.7167 (0.8274)  loss_bbox_2: 0.4251 (0.4499)  loss_giou_2: 0.3081 (0.3096)  loss_ce_enc: 1.3304 (1.3318)  loss_bbox_enc: 0.2940 (0.3447)  loss_giou_enc: 0.2503 (0.2721)  loss_ce_unscaled: 0.7099 (0.8088)  class_error_unscaled: 0.0000 (0.0498)  loss_bbox_unscaled: 0.0829 (0.0902)  loss_giou_unscaled: 0.1537 (0.1548)  cardinality_error_unscaled: 1.0000 (3.2392)  loss_ce_0_unscaled: 1.0550 (1.2246)  loss_bbox_0_unscaled: 0.0725 (0.0701)  loss_giou_0_unscaled: 0.1370 (0.1328)  cardinality_error_0_unscaled: 1.0000 (9.3744)  loss_ce_1_unscaled: 0.7948 (0.9319)  loss_bbox_1_unscaled: 0.0836 (0.0851)  loss_giou_1_unscaled: 0.1423 (0.1498)  cardinality_error_1_unscaled: 1.0000 (11.1582)  loss_ce_2_unscaled: 0.7167 (0.8274)  loss_bbox_2_unscaled: 0.0850 (0.0900)  loss_giou_2_unscaled: 0.1540 (0.1548)  cardinality_error_2_unscaled: 1.6250 (5.8520)  loss_ce_enc_unscaled: 1.3304 (1.3318)  loss_bbox_enc_unscaled: 0.0588 (0.0689)  loss_giou_enc_unscaled: 0.1251 (0.1361)  cardinality_error_enc_unscaled: 1.0000 (108.2366)  time: 0.9276  data: 0.0391  max mem: 8220
# Epoch: [0] Total time: 0:03:07 (0.9553 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 7.8286 (8.6026)  loss_ce: 0.7099 (0.8088)  loss_bbox: 0.4143 (0.4508)  loss_giou: 0.3074 (0.3095)  loss_ce_0: 1.0550 (1.2246)  loss_bbox_0: 0.3625 (0.3504)  loss_giou_0: 0.2740 (0.2657)  loss_ce_1: 0.7948 (0.9319)  loss_bbox_1: 0.4178 (0.4257)  loss_giou_1: 0.2845 (0.2997)  loss_ce_2: 0.7167 (0.8274)  loss_bbox_2: 0.4251 (0.4499)  loss_giou_2: 0.3081 (0.3096)  loss_ce_enc: 1.3304 (1.3318)  loss_bbox_enc: 0.2940 (0.3447)  loss_giou_enc: 0.2503 (0.2721)  loss_ce_unscaled: 0.7099 (0.8088)  class_error_unscaled: 0.0000 (0.0498)  loss_bbox_unscaled: 0.0829 (0.0902)  loss_giou_unscaled: 0.1537 (0.1548)  cardinality_error_unscaled: 1.0000 (3.2392)  loss_ce_0_unscaled: 1.0550 (1.2246)  loss_bbox_0_unscaled: 0.0725 (0.0701)  loss_giou_0_unscaled: 0.1370 (0.1328)  cardinality_error_0_unscaled: 1.0000 (9.3744)  loss_ce_1_unscaled: 0.7948 (0.9319)  loss_bbox_1_unscaled: 0.0836 (0.0851)  loss_giou_1_unscaled: 0.1423 (0.1498)  cardinality_error_1_unscaled: 1.0000 (11.1582)  loss_ce_2_unscaled: 0.7167 (0.8274)  loss_bbox_2_unscaled: 0.0850 (0.0900)  loss_giou_2_unscaled: 0.1540 (0.1548)  cardinality_error_2_unscaled: 1.6250 (5.8520)  loss_ce_enc_unscaled: 1.3304 (1.3318)  loss_bbox_enc_unscaled: 0.0588 (0.0689)  loss_giou_enc_unscaled: 0.1251 (0.1361)  cardinality_error_enc_unscaled: 1.0000 (108.2366)
# Test:  [  0/113]  eta: 0:00:55  class_error: 0.00  loss: 7.9715 (7.9715)  loss_ce: 0.5469 (0.5469)  loss_bbox: 0.7606 (0.7606)  loss_giou: 0.3593 (0.3593)  loss_ce_0: 1.0469 (1.0469)  loss_bbox_0: 0.2849 (0.2849)  loss_giou_0: 0.2447 (0.2447)  loss_ce_1: 0.7578 (0.7578)  loss_bbox_1: 0.4086 (0.4086)  loss_giou_1: 0.2734 (0.2734)  loss_ce_2: 0.8281 (0.8281)  loss_bbox_2: 0.3877 (0.3877)  loss_giou_2: 0.2648 (0.2648)  loss_ce_enc: 1.0312 (1.0312)  loss_bbox_enc: 0.4410 (0.4410)  loss_giou_enc: 0.3357 (0.3357)  loss_ce_unscaled: 0.5469 (0.5469)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.1521 (0.1521)  loss_giou_unscaled: 0.1797 (0.1797)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.0469 (1.0469)  loss_bbox_0_unscaled: 0.0570 (0.0570)  loss_giou_0_unscaled: 0.1223 (0.1223)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.7578 (0.7578)  loss_bbox_1_unscaled: 0.0817 (0.0817)  loss_giou_1_unscaled: 0.1367 (0.1367)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_2_unscaled: 0.8281 (0.8281)  loss_bbox_2_unscaled: 0.0775 (0.0775)  loss_giou_2_unscaled: 0.1324 (0.1324)  cardinality_error_2_unscaled: 0.8750 (0.8750)  loss_ce_enc_unscaled: 1.0312 (1.0312)  loss_bbox_enc_unscaled: 0.0882 (0.0882)  loss_giou_enc_unscaled: 0.1678 (0.1678)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.4953  data: 0.3228  max mem: 8220
# Test:  [ 10/113]  eta: 0:00:22  class_error: 0.00  loss: 7.1838 (7.2281)  loss_ce: 0.5938 (0.6000)  loss_bbox: 0.3624 (0.4135)  loss_giou: 0.2653 (0.2882)  loss_ce_0: 0.9219 (0.9517)  loss_bbox_0: 0.3653 (0.3442)  loss_giou_0: 0.2520 (0.2658)  loss_ce_1: 0.6289 (0.6708)  loss_bbox_1: 0.3664 (0.3753)  loss_giou_1: 0.2486 (0.2749)  loss_ce_2: 0.6172 (0.6424)  loss_bbox_2: 0.3819 (0.3780)  loss_giou_2: 0.2648 (0.2771)  loss_ce_enc: 1.1328 (1.1364)  loss_bbox_enc: 0.3133 (0.3322)  loss_giou_enc: 0.2887 (0.2777)  loss_ce_unscaled: 0.5938 (0.6000)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0725 (0.0827)  loss_giou_unscaled: 0.1327 (0.1441)  cardinality_error_unscaled: 1.0000 (0.9773)  loss_ce_0_unscaled: 0.9219 (0.9517)  loss_bbox_0_unscaled: 0.0731 (0.0688)  loss_giou_0_unscaled: 0.1260 (0.1329)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6289 (0.6708)  loss_bbox_1_unscaled: 0.0733 (0.0751)  loss_giou_1_unscaled: 0.1243 (0.1374)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_2_unscaled: 0.6172 (0.6424)  loss_bbox_2_unscaled: 0.0764 (0.0756)  loss_giou_2_unscaled: 0.1324 (0.1385)  cardinality_error_2_unscaled: 1.0000 (0.9318)  loss_ce_enc_unscaled: 1.1328 (1.1364)  loss_bbox_enc_unscaled: 0.0627 (0.0664)  loss_giou_enc_unscaled: 0.1444 (0.1388)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.2230  data: 0.0534  max mem: 8220
# Test:  [ 20/113]  eta: 0:00:17  class_error: 0.00  loss: 6.8313 (7.1744)  loss_ce: 0.5938 (0.5926)  loss_bbox: 0.3796 (0.4071)  loss_giou: 0.2653 (0.2782)  loss_ce_0: 0.9570 (0.9626)  loss_bbox_0: 0.3315 (0.3364)  loss_giou_0: 0.2450 (0.2563)  loss_ce_1: 0.6172 (0.6758)  loss_bbox_1: 0.3718 (0.3710)  loss_giou_1: 0.2486 (0.2659)  loss_ce_2: 0.6016 (0.6390)  loss_bbox_2: 0.3701 (0.3763)  loss_giou_2: 0.2568 (0.2680)  loss_ce_enc: 1.1328 (1.1343)  loss_bbox_enc: 0.3251 (0.3379)  loss_giou_enc: 0.2718 (0.2730)  loss_ce_unscaled: 0.5938 (0.5926)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0759 (0.0814)  loss_giou_unscaled: 0.1327 (0.1391)  cardinality_error_unscaled: 1.0000 (0.9821)  loss_ce_0_unscaled: 0.9570 (0.9626)  loss_bbox_0_unscaled: 0.0663 (0.0673)  loss_giou_0_unscaled: 0.1225 (0.1282)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6172 (0.6758)  loss_bbox_1_unscaled: 0.0744 (0.0742)  loss_giou_1_unscaled: 0.1243 (0.1329)  cardinality_error_1_unscaled: 1.0000 (0.9940)  loss_ce_2_unscaled: 0.6016 (0.6390)  loss_bbox_2_unscaled: 0.0740 (0.0753)  loss_giou_2_unscaled: 0.1284 (0.1340)  cardinality_error_2_unscaled: 1.0000 (0.9345)  loss_ce_enc_unscaled: 1.1328 (1.1343)  loss_bbox_enc_unscaled: 0.0650 (0.0676)  loss_giou_enc_unscaled: 0.1359 (0.1365)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1697  data: 0.0272  max mem: 8220
# Test:  [ 30/113]  eta: 0:00:14  class_error: 0.00  loss: 6.9832 (7.2073)  loss_ce: 0.6016 (0.6001)  loss_bbox: 0.3879 (0.4036)  loss_giou: 0.2704 (0.2841)  loss_ce_0: 0.9570 (0.9611)  loss_bbox_0: 0.3252 (0.3343)  loss_giou_0: 0.2517 (0.2630)  loss_ce_1: 0.6367 (0.6744)  loss_bbox_1: 0.3731 (0.3715)  loss_giou_1: 0.2664 (0.2720)  loss_ce_2: 0.6211 (0.6384)  loss_bbox_2: 0.3536 (0.3796)  loss_giou_2: 0.2552 (0.2755)  loss_ce_enc: 1.1172 (1.1206)  loss_bbox_enc: 0.3356 (0.3446)  loss_giou_enc: 0.2734 (0.2845)  loss_ce_unscaled: 0.6016 (0.6001)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0776 (0.0807)  loss_giou_unscaled: 0.1352 (0.1421)  cardinality_error_unscaled: 1.0000 (0.9798)  loss_ce_0_unscaled: 0.9570 (0.9611)  loss_bbox_0_unscaled: 0.0650 (0.0669)  loss_giou_0_unscaled: 0.1258 (0.1315)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6367 (0.6744)  loss_bbox_1_unscaled: 0.0746 (0.0743)  loss_giou_1_unscaled: 0.1332 (0.1360)  cardinality_error_1_unscaled: 1.0000 (0.9839)  loss_ce_2_unscaled: 0.6211 (0.6384)  loss_bbox_2_unscaled: 0.0707 (0.0759)  loss_giou_2_unscaled: 0.1276 (0.1378)  cardinality_error_2_unscaled: 1.0000 (0.9516)  loss_ce_enc_unscaled: 1.1172 (1.1206)  loss_bbox_enc_unscaled: 0.0671 (0.0689)  loss_giou_enc_unscaled: 0.1367 (0.1423)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1419  data: 0.0264  max mem: 8220
# Test:  [ 40/113]  eta: 0:00:12  class_error: 0.00  loss: 7.1354 (7.2724)  loss_ce: 0.6094 (0.6015)  loss_bbox: 0.3926 (0.4074)  loss_giou: 0.2970 (0.2920)  loss_ce_0: 0.9258 (0.9426)  loss_bbox_0: 0.3564 (0.3527)  loss_giou_0: 0.2999 (0.2779)  loss_ce_1: 0.6406 (0.6702)  loss_bbox_1: 0.3895 (0.3798)  loss_giou_1: 0.2942 (0.2816)  loss_ce_2: 0.6133 (0.6321)  loss_bbox_2: 0.3918 (0.3889)  loss_giou_2: 0.3027 (0.2857)  loss_ce_enc: 1.0703 (1.1129)  loss_bbox_enc: 0.3651 (0.3531)  loss_giou_enc: 0.2973 (0.2940)  loss_ce_unscaled: 0.6094 (0.6015)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0785 (0.0815)  loss_giou_unscaled: 0.1485 (0.1460)  cardinality_error_unscaled: 1.0000 (0.9848)  loss_ce_0_unscaled: 0.9258 (0.9426)  loss_bbox_0_unscaled: 0.0713 (0.0705)  loss_giou_0_unscaled: 0.1500 (0.1390)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6406 (0.6702)  loss_bbox_1_unscaled: 0.0779 (0.0760)  loss_giou_1_unscaled: 0.1471 (0.1408)  cardinality_error_1_unscaled: 1.0000 (0.9878)  loss_ce_2_unscaled: 0.6133 (0.6321)  loss_bbox_2_unscaled: 0.0784 (0.0778)  loss_giou_2_unscaled: 0.1513 (0.1428)  cardinality_error_2_unscaled: 1.0000 (0.9482)  loss_ce_enc_unscaled: 1.0703 (1.1129)  loss_bbox_enc_unscaled: 0.0730 (0.0706)  loss_giou_enc_unscaled: 0.1487 (0.1470)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1593  data: 0.0254  max mem: 8220
# Test:  [ 50/113]  eta: 0:00:10  class_error: 0.00  loss: 7.3000 (7.3569)  loss_ce: 0.6328 (0.6252)  loss_bbox: 0.4020 (0.4062)  loss_giou: 0.2737 (0.2902)  loss_ce_0: 0.9102 (0.9464)  loss_bbox_0: 0.3842 (0.3571)  loss_giou_0: 0.2915 (0.2772)  loss_ce_1: 0.6602 (0.6836)  loss_bbox_1: 0.4082 (0.3877)  loss_giou_1: 0.2956 (0.2842)  loss_ce_2: 0.6406 (0.6489)  loss_bbox_2: 0.4270 (0.3972)  loss_giou_2: 0.2966 (0.2884)  loss_ce_enc: 1.0781 (1.1191)  loss_bbox_enc: 0.3576 (0.3545)  loss_giou_enc: 0.2896 (0.2910)  loss_ce_unscaled: 0.6328 (0.6252)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0804 (0.0812)  loss_giou_unscaled: 0.1369 (0.1451)  cardinality_error_unscaled: 1.0000 (0.9877)  loss_ce_0_unscaled: 0.9102 (0.9464)  loss_bbox_0_unscaled: 0.0768 (0.0714)  loss_giou_0_unscaled: 0.1458 (0.1386)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6602 (0.6836)  loss_bbox_1_unscaled: 0.0816 (0.0775)  loss_giou_1_unscaled: 0.1478 (0.1421)  cardinality_error_1_unscaled: 1.0000 (0.9902)  loss_ce_2_unscaled: 0.6406 (0.6489)  loss_bbox_2_unscaled: 0.0854 (0.0794)  loss_giou_2_unscaled: 0.1483 (0.1442)  cardinality_error_2_unscaled: 0.8750 (0.9461)  loss_ce_enc_unscaled: 1.0781 (1.1191)  loss_bbox_enc_unscaled: 0.0715 (0.0709)  loss_giou_enc_unscaled: 0.1448 (0.1455)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1600  data: 0.0254  max mem: 8220
# Test:  [ 60/113]  eta: 0:00:08  class_error: 0.00  loss: 7.4222 (7.3751)  loss_ce: 0.6367 (0.6265)  loss_bbox: 0.3884 (0.4060)  loss_giou: 0.2737 (0.2899)  loss_ce_0: 0.9570 (0.9485)  loss_bbox_0: 0.3797 (0.3598)  loss_giou_0: 0.2688 (0.2781)  loss_ce_1: 0.6680 (0.6863)  loss_bbox_1: 0.3927 (0.3876)  loss_giou_1: 0.2784 (0.2840)  loss_ce_2: 0.6602 (0.6515)  loss_bbox_2: 0.4020 (0.3985)  loss_giou_2: 0.2872 (0.2882)  loss_ce_enc: 1.1172 (1.1204)  loss_bbox_enc: 0.3531 (0.3570)  loss_giou_enc: 0.2857 (0.2928)  loss_ce_unscaled: 0.6367 (0.6265)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0777 (0.0812)  loss_giou_unscaled: 0.1369 (0.1450)  cardinality_error_unscaled: 1.0000 (0.9857)  loss_ce_0_unscaled: 0.9570 (0.9485)  loss_bbox_0_unscaled: 0.0759 (0.0720)  loss_giou_0_unscaled: 0.1344 (0.1391)  cardinality_error_0_unscaled: 1.0000 (0.9980)  loss_ce_1_unscaled: 0.6680 (0.6863)  loss_bbox_1_unscaled: 0.0785 (0.0775)  loss_giou_1_unscaled: 0.1392 (0.1420)  cardinality_error_1_unscaled: 1.0000 (0.9898)  loss_ce_2_unscaled: 0.6602 (0.6515)  loss_bbox_2_unscaled: 0.0804 (0.0797)  loss_giou_2_unscaled: 0.1436 (0.1441)  cardinality_error_2_unscaled: 0.8750 (0.9406)  loss_ce_enc_unscaled: 1.1172 (1.1204)  loss_bbox_enc_unscaled: 0.0706 (0.0714)  loss_giou_enc_unscaled: 0.1428 (0.1464)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1594  data: 0.0253  max mem: 8220
# Test:  [ 70/113]  eta: 0:00:07  class_error: 0.00  loss: 7.2645 (7.4034)  loss_ce: 0.6367 (0.6293)  loss_bbox: 0.3879 (0.4065)  loss_giou: 0.2838 (0.2903)  loss_ce_0: 0.9609 (0.9510)  loss_bbox_0: 0.3516 (0.3643)  loss_giou_0: 0.2707 (0.2790)  loss_ce_1: 0.6836 (0.6880)  loss_bbox_1: 0.3704 (0.3900)  loss_giou_1: 0.2706 (0.2842)  loss_ce_2: 0.6641 (0.6524)  loss_bbox_2: 0.3976 (0.4016)  loss_giou_2: 0.2758 (0.2883)  loss_ce_enc: 1.1484 (1.1256)  loss_bbox_enc: 0.3655 (0.3593)  loss_giou_enc: 0.2927 (0.2935)  loss_ce_unscaled: 0.6367 (0.6293)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0776 (0.0813)  loss_giou_unscaled: 0.1419 (0.1451)  cardinality_error_unscaled: 1.0000 (0.9859)  loss_ce_0_unscaled: 0.9609 (0.9510)  loss_bbox_0_unscaled: 0.0703 (0.0729)  loss_giou_0_unscaled: 0.1354 (0.1395)  cardinality_error_0_unscaled: 1.0000 (0.9982)  loss_ce_1_unscaled: 0.6836 (0.6880)  loss_bbox_1_unscaled: 0.0741 (0.0780)  loss_giou_1_unscaled: 0.1353 (0.1421)  cardinality_error_1_unscaled: 1.0000 (0.9894)  loss_ce_2_unscaled: 0.6641 (0.6524)  loss_bbox_2_unscaled: 0.0795 (0.0803)  loss_giou_2_unscaled: 0.1379 (0.1442)  cardinality_error_2_unscaled: 1.0000 (0.9507)  loss_ce_enc_unscaled: 1.1484 (1.1256)  loss_bbox_enc_unscaled: 0.0731 (0.0719)  loss_giou_enc_unscaled: 0.1463 (0.1467)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.1599  data: 0.0252  max mem: 8220
# ...
# Accumulating evaluation results...
# DONE (t=0.74s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.720
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.952
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.865
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.619
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.842
# Training time 0:19:17
# Results saved to output/results.json
# Test:  [ 0/57]  eta: 0:00:29  class_error: 0.00  loss: 8.1242 (8.1242)  loss_ce: 0.5391 (0.5391)  loss_bbox: 0.6644 (0.6644)  loss_giou: 0.3586 (0.3586)  loss_ce_0: 0.7031 (0.7031)  loss_bbox_0: 0.5629 (0.5629)  loss_giou_0: 0.3272 (0.3272)  loss_ce_1: 0.6484 (0.6484)  loss_bbox_1: 0.6478 (0.6478)  loss_giou_1: 0.3479 (0.3479)  loss_ce_2: 0.5547 (0.5547)  loss_bbox_2: 0.6651 (0.6651)  loss_giou_2: 0.3580 (0.3580)  loss_ce_enc: 0.8086 (0.8086)  loss_bbox_enc: 0.5787 (0.5787)  loss_giou_enc: 0.3599 (0.3599)  loss_ce_unscaled: 0.5391 (0.5391)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.1329 (0.1329)  loss_giou_unscaled: 0.1793 (0.1793)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 0.7031 (0.7031)  loss_bbox_0_unscaled: 0.1126 (0.1126)  loss_giou_0_unscaled: 0.1636 (0.1636)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6484 (0.6484)  loss_bbox_1_unscaled: 0.1296 (0.1296)  loss_giou_1_unscaled: 0.1739 (0.1739)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_2_unscaled: 0.5547 (0.5547)  loss_bbox_2_unscaled: 0.1330 (0.1330)  loss_giou_2_unscaled: 0.1790 (0.1790)  cardinality_error_2_unscaled: 0.8750 (0.8750)  loss_ce_enc_unscaled: 0.8086 (0.8086)  loss_bbox_enc_unscaled: 0.1157 (0.1157)  loss_giou_enc_unscaled: 0.1799 (0.1799)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 0.5230  data: 0.3291  max mem: 8220
# Test:  [10/57]  eta: 0:00:09  class_error: 0.00  loss: 6.4497 (6.4588)  loss_ce: 0.5273 (0.5234)  loss_bbox: 0.3320 (0.3902)  loss_giou: 0.2693 (0.2643)  loss_ce_0: 0.6211 (0.6163)  loss_bbox_0: 0.3155 (0.3986)  loss_giou_0: 0.2722 (0.2683)  loss_ce_1: 0.5664 (0.5574)  loss_bbox_1: 0.3192 (0.3942)  loss_giou_1: 0.2633 (0.2693)  loss_ce_2: 0.5352 (0.5314)  loss_bbox_2: 0.3317 (0.3890)  loss_giou_2: 0.2705 (0.2656)  loss_ce_enc: 0.7539 (0.7124)  loss_bbox_enc: 0.5197 (0.5346)  loss_giou_enc: 0.3283 (0.3439)  loss_ce_unscaled: 0.5273 (0.5234)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0664 (0.0780)  loss_giou_unscaled: 0.1346 (0.1322)  cardinality_error_unscaled: 1.0000 (1.0795)  loss_ce_0_unscaled: 0.6211 (0.6163)  loss_bbox_0_unscaled: 0.0631 (0.0797)  loss_giou_0_unscaled: 0.1361 (0.1342)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.5664 (0.5574)  loss_bbox_1_unscaled: 0.0638 (0.0788)  loss_giou_1_unscaled: 0.1316 (0.1347)  cardinality_error_1_unscaled: 1.0000 (1.0341)  loss_ce_2_unscaled: 0.5352 (0.5314)  loss_bbox_2_unscaled: 0.0663 (0.0778)  loss_giou_2_unscaled: 0.1353 (0.1328)  cardinality_error_2_unscaled: 0.8750 (0.9091)  loss_ce_enc_unscaled: 0.7539 (0.7124)  loss_bbox_enc_unscaled: 0.1039 (0.1069)  loss_giou_enc_unscaled: 0.1642 (0.1719)  cardinality_error_enc_unscaled: 1.0000 (0.9773)  time: 0.1978  data: 0.0553  max mem: 8220
# Test:  [20/57]  eta: 0:00:07  class_error: 0.00  loss: 6.2849 (6.4196)  loss_ce: 0.5195 (0.5273)  loss_bbox: 0.3434 (0.3905)  loss_giou: 0.2693 (0.2763)  loss_ce_0: 0.5781 (0.6047)  loss_bbox_0: 0.3664 (0.3932)  loss_giou_0: 0.2722 (0.2789)  loss_ce_1: 0.5117 (0.5504)  loss_bbox_1: 0.3652 (0.3937)  loss_giou_1: 0.2836 (0.2788)  loss_ce_2: 0.5234 (0.5347)  loss_bbox_2: 0.3472 (0.3869)  loss_giou_2: 0.2705 (0.2753)  loss_ce_enc: 0.6836 (0.7024)  loss_bbox_enc: 0.4674 (0.4883)  loss_giou_enc: 0.3295 (0.3381)  loss_ce_unscaled: 0.5195 (0.5273)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0687 (0.0781)  loss_giou_unscaled: 0.1346 (0.1382)  cardinality_error_unscaled: 0.8750 (0.9940)  loss_ce_0_unscaled: 0.5781 (0.6047)  loss_bbox_0_unscaled: 0.0733 (0.0786)  loss_giou_0_unscaled: 0.1361 (0.1394)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.5117 (0.5504)  loss_bbox_1_unscaled: 0.0730 (0.0787)  loss_giou_1_unscaled: 0.1418 (0.1394)  cardinality_error_1_unscaled: 1.0000 (1.0060)  loss_ce_2_unscaled: 0.5234 (0.5347)  loss_bbox_2_unscaled: 0.0694 (0.0774)  loss_giou_2_unscaled: 0.1353 (0.1377)  cardinality_error_2_unscaled: 0.8750 (0.9048)  loss_ce_enc_unscaled: 0.6836 (0.7024)  loss_bbox_enc_unscaled: 0.0935 (0.0977)  loss_giou_enc_unscaled: 0.1648 (0.1690)  cardinality_error_enc_unscaled: 1.0000 (0.9881)  time: 0.1917  data: 0.0270  max mem: 8220
# Test:  [30/57]  eta: 0:00:05  class_error: 0.00  loss: 5.7415 (6.1193)  loss_ce: 0.4336 (0.5106)  loss_bbox: 0.3523 (0.3645)  loss_giou: 0.2613 (0.2643)  loss_ce_0: 0.4844 (0.5824)  loss_bbox_0: 0.3664 (0.3661)  loss_giou_0: 0.2672 (0.2670)  loss_ce_1: 0.4707 (0.5347)  loss_bbox_1: 0.3652 (0.3689)  loss_giou_1: 0.2827 (0.2666)  loss_ce_2: 0.4473 (0.5154)  loss_bbox_2: 0.3586 (0.3659)  loss_giou_2: 0.2689 (0.2664)  loss_ce_enc: 0.6406 (0.6873)  loss_bbox_enc: 0.3693 (0.4452)  loss_giou_enc: 0.2921 (0.3141)  loss_ce_unscaled: 0.4336 (0.5106)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0705 (0.0729)  loss_giou_unscaled: 0.1307 (0.1321)  cardinality_error_unscaled: 1.0000 (1.0444)  loss_ce_0_unscaled: 0.4844 (0.5824)  loss_bbox_0_unscaled: 0.0733 (0.0732)  loss_giou_0_unscaled: 0.1336 (0.1335)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.4707 (0.5347)  loss_bbox_1_unscaled: 0.0730 (0.0738)  loss_giou_1_unscaled: 0.1413 (0.1333)  cardinality_error_1_unscaled: 1.0000 (0.9758)  loss_ce_2_unscaled: 0.4473 (0.5154)  loss_bbox_2_unscaled: 0.0717 (0.0732)  loss_giou_2_unscaled: 0.1344 (0.1332)  cardinality_error_2_unscaled: 0.8750 (0.8911)  loss_ce_enc_unscaled: 0.6406 (0.6873)  loss_bbox_enc_unscaled: 0.0739 (0.0890)  loss_giou_enc_unscaled: 0.1460 (0.1571)  cardinality_error_enc_unscaled: 1.0000 (0.9919)  time: 0.1890  data: 0.0254  max mem: 8220
# Test:  [40/57]  eta: 0:00:03  class_error: 0.00  loss: 5.7415 (6.4454)  loss_ce: 0.4609 (0.5294)  loss_bbox: 0.3598 (0.4059)  loss_giou: 0.2581 (0.2806)  loss_ce_0: 0.5039 (0.5932)  loss_bbox_0: 0.3752 (0.4036)  loss_giou_0: 0.2645 (0.2807)  loss_ce_1: 0.4707 (0.5454)  loss_bbox_1: 0.3805 (0.4115)  loss_giou_1: 0.2686 (0.2838)  loss_ce_2: 0.4570 (0.5302)  loss_bbox_2: 0.3720 (0.4099)  loss_giou_2: 0.2765 (0.2833)  loss_ce_enc: 0.6406 (0.7091)  loss_bbox_enc: 0.3961 (0.4592)  loss_giou_enc: 0.2921 (0.3195)  loss_ce_unscaled: 0.4609 (0.5294)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0720 (0.0812)  loss_giou_unscaled: 0.1291 (0.1403)  cardinality_error_unscaled: 1.1250 (1.0396)  loss_ce_0_unscaled: 0.5039 (0.5932)  loss_bbox_0_unscaled: 0.0750 (0.0807)  loss_giou_0_unscaled: 0.1323 (0.1404)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.4707 (0.5454)  loss_bbox_1_unscaled: 0.0761 (0.0823)  loss_giou_1_unscaled: 0.1343 (0.1419)  cardinality_error_1_unscaled: 1.0000 (0.9848)  loss_ce_2_unscaled: 0.4570 (0.5302)  loss_bbox_2_unscaled: 0.0744 (0.0820)  loss_giou_2_unscaled: 0.1383 (0.1417)  cardinality_error_2_unscaled: 0.8750 (0.8780)  loss_ce_enc_unscaled: 0.6406 (0.7091)  loss_bbox_enc_unscaled: 0.0792 (0.0918)  loss_giou_enc_unscaled: 0.1460 (0.1598)  cardinality_error_enc_unscaled: 1.0000 (1.0030)  time: 0.1803  data: 0.0247  max mem: 8220
# Test:  [50/57]  eta: 0:00:01  class_error: 0.00  loss: 6.2105 (6.3622)  loss_ce: 0.5273 (0.5255)  loss_bbox: 0.4065 (0.4010)  loss_giou: 0.2581 (0.2755)  loss_ce_0: 0.6211 (0.5870)  loss_bbox_0: 0.3904 (0.3968)  loss_giou_0: 0.2524 (0.2754)  loss_ce_1: 0.5391 (0.5414)  loss_bbox_1: 0.4237 (0.4049)  loss_giou_1: 0.2545 (0.2781)  loss_ce_2: 0.5312 (0.5272)  loss_bbox_2: 0.4310 (0.4039)  loss_giou_2: 0.2644 (0.2778)  loss_ce_enc: 0.7344 (0.7057)  loss_bbox_enc: 0.4168 (0.4498)  loss_giou_enc: 0.3030 (0.3123)  loss_ce_unscaled: 0.5273 (0.5255)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0813 (0.0802)  loss_giou_unscaled: 0.1291 (0.1378)  cardinality_error_unscaled: 1.0000 (1.1029)  loss_ce_0_unscaled: 0.6211 (0.5870)  loss_bbox_0_unscaled: 0.0781 (0.0794)  loss_giou_0_unscaled: 0.1262 (0.1377)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.5391 (0.5414)  loss_bbox_1_unscaled: 0.0847 (0.0810)  loss_giou_1_unscaled: 0.1272 (0.1390)  cardinality_error_1_unscaled: 1.0000 (0.9804)  loss_ce_2_unscaled: 0.5312 (0.5272)  loss_bbox_2_unscaled: 0.0862 (0.0808)  loss_giou_2_unscaled: 0.1322 (0.1389)  cardinality_error_2_unscaled: 0.8750 (0.9118)  loss_ce_enc_unscaled: 0.7344 (0.7057)  loss_bbox_enc_unscaled: 0.0834 (0.0900)  loss_giou_enc_unscaled: 0.1515 (0.1561)  cardinality_error_enc_unscaled: 1.0000 (1.0270)  time: 0.1808  data: 0.0249  max mem: 8220
# Test:  [56/57]  eta: 0:00:00  class_error: 0.00  loss: 6.2906 (6.4097)  loss_ce: 0.5234 (0.5287)  loss_bbox: 0.4210 (0.4050)  loss_giou: 0.2592 (0.2773)  loss_ce_0: 0.5625 (0.5875)  loss_bbox_0: 0.4003 (0.4027)  loss_giou_0: 0.2487 (0.2776)  loss_ce_1: 0.5312 (0.5443)  loss_bbox_1: 0.4124 (0.4082)  loss_giou_1: 0.2509 (0.2795)  loss_ce_2: 0.5195 (0.5318)  loss_bbox_2: 0.4249 (0.4083)  loss_giou_2: 0.2644 (0.2798)  loss_ce_enc: 0.6953 (0.7083)  loss_bbox_enc: 0.4168 (0.4561)  loss_giou_enc: 0.3027 (0.3145)  loss_ce_unscaled: 0.5234 (0.5287)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0842 (0.0810)  loss_giou_unscaled: 0.1296 (0.1387)  cardinality_error_unscaled: 1.0000 (1.1184)  loss_ce_0_unscaled: 0.5625 (0.5875)  loss_bbox_0_unscaled: 0.0801 (0.0805)  loss_giou_0_unscaled: 0.1244 (0.1388)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.5312 (0.5443)  loss_bbox_1_unscaled: 0.0825 (0.0816)  loss_giou_1_unscaled: 0.1255 (0.1398)  cardinality_error_1_unscaled: 1.0000 (0.9781)  loss_ce_2_unscaled: 0.5195 (0.5318)  loss_bbox_2_unscaled: 0.0850 (0.0817)  loss_giou_2_unscaled: 0.1322 (0.1399)  cardinality_error_2_unscaled: 0.8750 (0.8860)  loss_ce_enc_unscaled: 0.6953 (0.7083)  loss_bbox_enc_unscaled: 0.0834 (0.0912)  loss_giou_enc_unscaled: 0.1514 (0.1572)  cardinality_error_enc_unscaled: 1.0000 (1.0570)  time: 0.1780  data: 0.0242  max mem: 8220
# Test: Total time: 0:00:10 (0.1854 s / it)
# Averaged stats: class_error: 0.00  loss: 6.2906 (6.4097)  loss_ce: 0.5234 (0.5287)  loss_bbox: 0.4210 (0.4050)  loss_giou: 0.2592 (0.2773)  loss_ce_0: 0.5625 (0.5875)  loss_bbox_0: 0.4003 (0.4027)  loss_giou_0: 0.2487 (0.2776)  loss_ce_1: 0.5312 (0.5443)  loss_bbox_1: 0.4124 (0.4082)  loss_giou_1: 0.2509 (0.2795)  loss_ce_2: 0.5195 (0.5318)  loss_bbox_2: 0.4249 (0.4083)  loss_giou_2: 0.2644 (0.2798)  loss_ce_enc: 0.6953 (0.7083)  loss_bbox_enc: 0.4168 (0.4561)  loss_giou_enc: 0.3027 (0.3145)  loss_ce_unscaled: 0.5234 (0.5287)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0842 (0.0810)  loss_giou_unscaled: 0.1296 (0.1387)  cardinality_error_unscaled: 1.0000 (1.1184)  loss_ce_0_unscaled: 0.5625 (0.5875)  loss_bbox_0_unscaled: 0.0801 (0.0805)  loss_giou_0_unscaled: 0.1244 (0.1388)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.5312 (0.5443)  loss_bbox_1_unscaled: 0.0825 (0.0816)  loss_giou_1_unscaled: 0.1255 (0.1398)  cardinality_error_1_unscaled: 1.0000 (0.9781)  loss_ce_2_unscaled: 0.5195 (0.5318)  loss_bbox_2_unscaled: 0.0850 (0.0817)  loss_giou_2_unscaled: 0.1322 (0.1399)  cardinality_error_2_unscaled: 0.8750 (0.8860)  loss_ce_enc_unscaled: 0.6953 (0.7083)  loss_bbox_enc_unscaled: 0.0834 (0.0912)  loss_giou_enc_unscaled: 0.1514 (0.1572)  cardinality_error_enc_unscaled: 1.0000 (1.0570)
# Accumulating evaluation results...
# DONE (t=0.37s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.807
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.697
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.838
# Test results: {'class_error': 0.0, 'loss': 6.409704593189976, 'loss_ce': 0.5287486293859649, 'loss_bbox': 0.40499482865919145, 'loss_giou': 0.27734587903608354, 'loss_ce_0': 0.5874794407894737, 'loss_bbox_0': 0.40273392827887283, 'loss_giou_0': 0.27756971748251663, 'loss_ce_1': 0.5443050986842105, 'loss_bbox_1': 0.4081551325425767, 'loss_giou_1': 0.27953660278989556, 'loss_ce_2': 0.5317639802631579, 'loss_bbox_2': 0.40834312350080726, 'loss_giou_2': 0.27982404958783536, 'loss_ce_enc': 0.7083333333333334, 'loss_bbox_enc': 0.4561140009185724, 'loss_giou_enc': 0.3144567990512179, 'loss_ce_unscaled': 0.5287486293859649, 'class_error_unscaled': 0.0, 'loss_bbox_unscaled': 0.0809989657187671, 'loss_giou_unscaled': 0.13867293951804177, 'cardinality_error_unscaled': 1.118421052631579, 'loss_ce_0_unscaled': 0.5874794407894737, 'loss_bbox_0_unscaled': 0.08054678579955771, 'loss_giou_0_unscaled': 0.13878485874125832, 'cardinality_error_0_unscaled': 1.0, 'loss_ce_1_unscaled': 0.5443050986842105, 'loss_bbox_1_unscaled': 0.0816310263778034, 'loss_giou_1_unscaled': 0.13976830139494778, 'cardinality_error_1_unscaled': 0.9780701754385965, 'loss_ce_2_unscaled': 0.5317639802631579, 'loss_bbox_2_unscaled': 0.08166862462173428, 'loss_giou_2_unscaled': 0.13991202479391768, 'cardinality_error_2_unscaled': 0.8859649122807017, 'loss_ce_enc_unscaled': 0.7083333333333334, 'loss_bbox_enc_unscaled': 0.09122280018371448, 'loss_giou_enc_unscaled': 0.15722839952560894, 'cardinality_error_enc_unscaled': 1.0570175438596492, 'results_json': {'class_map': [{'class': 'Fall-Detected', 'map@50:95': 0.7019536483819498, 'map@50': 0.942952883950919, 'precision': 0.89587852494577, 'recall': 0.91}, {'class': 'all', 'map@50:95': 0.7019536483819498, 'map@50': 0.942952883950919, 'precision': 0.89587852494577, 'recall': 0.91}], 'map': 0.942952883950919, 'precision': 0.89587852494577, 'recall': 0.91}, 'coco_eval_bbox': [0.7019536483819498, 0.942952883950919, 0.8068099827137682, 0.25105105807411165, 0.6300963553603308, 0.7216632545685354, 0.6973333333333334, 0.7897777777777778, 0.8231111111111111, 0.8, 0.7651685393258426, 0.8376044568245125]}
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
# !ls -la /content/output
# Out:
# total 1436580
# drwxr-xr-x 3 root root      4096 Nov  4 02:21 .
# drwxr-xr-x 1 root root      4096 Nov  4 02:01 ..
# -rw-r--r-- 1 root root 401143226 Nov  4 02:21 checkpoint_best_ema.pth
# -rw-r--r-- 1 root root 401151446 Nov  4 02:13 checkpoint_best_regular.pth
# -rw-r--r-- 1 root root 133680367 Nov  4 02:21 checkpoint_best_total.pth
# -rw-r--r-- 1 root root 534804357 Nov  4 02:20 checkpoint.pth
# drwxr-xr-x 2 root root      4096 Nov  4 02:05 eval
# -rw-r--r-- 1 root root        88 Nov  4 01:55 events.out.tfevents.1762221359.21d46fbe3230.3512.0
# -rw-r--r-- 1 root root      2242 Nov  4 02:21 events.out.tfevents.1762221715.21d46fbe3230.6280.0
# -rw-r--r-- 1 root root     34681 Nov  4 02:21 log.txt
# -rw-r--r-- 1 root root    197230 Nov  4 02:21 metrics_plot.png
# -rw-r--r-- 1 root root       643 Nov  4 02:21 results.json

# %% [markdown]
# ## Deploy a Trained RF-DETR Model
#
# Deploying to Roboflow allows you to create multi-step computer vision applications that run both in the cloud and your own hardware. Please wait a moment while Roboflow indexes your model.

# %%
# model.deploy_to_roboflow(
#   workspace="roboflow-jvuqo",
#   project_id="basketball-player-detection-2",
#   version=13,
#   api_key=os.environ["ROBOFLOW_API_KEY"]
# )
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/13
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/model/13

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 146.49 MB | Reserved: 10432.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 146.49 MB | Reserved: 316.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRMedium(pretrain_weights="/content/output/checkpoint_best_total.pth")
model.optimize_for_inference()

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 169/169 [00:03<00:00, 44.91it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.908
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.580
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.321
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]                 = 0.758
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]                 = 0.809

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
# !pip install -q inference-gpu==0.51.7

# %%
from inference import get_model

MODEL_ID = "basketball-player-detection-2/13"
model_rf = get_model(model_id=MODEL_ID, api_key = userdata.get("ROBOFLOW_API_KEY"))

# %%
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

result = model_rf.infer(image, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %% [markdown]
# <div align="center">
#   <p>
#     Looking for more tutorials or have questions?
#     Check out our <a href="https://github.com/roboflow/notebooks">GitHub repo</a> for more notebooks,
#     or visit our <a href="https://discord.gg/GbfgXGJ8Bk">discord</a>.
#   </p>
#
#   <p>
#     <strong>If you found this helpful, please consider giving us a ⭐
#     <a href="https://github.com/roboflow/notebooks">on GitHub</a>!</strong>
#   </p>
#
# </div>
